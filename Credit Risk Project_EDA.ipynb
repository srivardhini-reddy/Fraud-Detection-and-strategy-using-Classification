# %% [markdown]
# # Importing Libraries #

# %%
# for DataFrames and manipulations
import pandas as pd
import numpy as np

# libaries to help with data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# removes the limit for the number of displayed columns
pd.set_option("display.max_columns", None)
# Sets the limit for the number of displayed rows
pd.set_option("display.max_rows", None)

# %% [markdown]
# # Importing Data #

# %%
data = pd.read_csv('df.csv')

# %%
# copying data to another variable to avoid any changes to original data
df = data.copy()

# %%
df.head(5)
# Out:
#    Unnamed: 0                                        customer_ID         S_2  \
# 0           0  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2018-02-21
# 1           1  00000fd6641609c6ece5454664794f0340ad84dddce9a2...  2017-03-01
# 2           2  00001b22f846c82c51f6e3958ccd81970162bae8b007e8...  2017-09-11
# 3           3  000041bdba6ecadd89a52d11886e8eaaec9325906c9723...  2017-08-06
# 4           4  00007889e4fcd2614b6cbe7f8f3d2e5c728eca32d9eb8a...  2017-11-29
#
#         P_2      D_39       B_1       B_2       R_1       S_3      D_41  \
# 0  0.937349  0.002425  0.019837  1.008307  0.000607  0.102985  0.006174
# 1  0.929122  0.382790  0.025782  1.002647  0.005515  0.089799  0.001479
# 2  0.904482  0.005470  0.006262  0.818312  0.005699       NaN  0.009560
# 3  0.594502  0.007465  0.012893  1.001205  0.009915  0.157413  0.006188
# 4  0.860753  0.008184  0.005732  0.814270  0.002764       NaN  0.006711
#
# ...

# %%
df = df.drop('Unnamed: 0', axis=1)
df.head(5)
# Out:
#                                          customer_ID         S_2       P_2  \
# 0  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2018-02-21  0.937349
# 1  00000fd6641609c6ece5454664794f0340ad84dddce9a2...  2017-03-01  0.929122
# 2  00001b22f846c82c51f6e3958ccd81970162bae8b007e8...  2017-09-11  0.904482
# 3  000041bdba6ecadd89a52d11886e8eaaec9325906c9723...  2017-08-06  0.594502
# 4  00007889e4fcd2614b6cbe7f8f3d2e5c728eca32d9eb8a...  2017-11-29  0.860753
#
#        D_39       B_1       B_2       R_1       S_3      D_41       B_3  D_42  \
# 0  0.002425  0.019837  1.008307  0.000607  0.102985  0.006174  0.007454   NaN
# 1  0.382790  0.025782  1.002647  0.005515  0.089799  0.001479  0.005830   NaN
# 2  0.005470  0.006262  0.818312  0.005699       NaN  0.009560  0.009063   NaN
# 3  0.007465  0.012893  1.001205  0.009915  0.157413  0.006188  0.004458   NaN
# 4  0.008184  0.005732  0.814270  0.002764       NaN  0.006711  0.006823   NaN
#
# ...

# %%
df.shape
# Out:
# (458913, 191)

# %%
df.dtypes
# Out:
# customer_ID     object
# S_2             object
# P_2            float64
# D_39           float64
# B_1            float64
# B_2            float64
# R_1            float64
# S_3            float64
# D_41           float64
# B_3            float64
# D_42           float64
# D_43           float64
# D_44           float64
# B_4            float64
# D_45           float64
# B_5            float64
# R_2            float64
# D_46           float64
# D_47           float64
# D_48           float64
# D_49           float64
# B_6            float64
# B_7            float64
# B_8            float64
# D_50           float64
# D_51           float64
# B_9            float64
# R_3            float64
# D_52           float64
# P_3            float64
# B_10           float64
# D_53           float64
# S_5            float64
# B_11           float64
# S_6            float64
# D_54           float64
# R_4            float64
# S_7            float64
# B_12           float64
# S_8            float64
# ...

# %%
#change dtype of S_2 to datetime
df['S_2'] = pd.to_datetime(df['S_2'])

# %%
print(df['S_2'].dtypes)
# Out:
# datetime64[ns]

# %%
# there are 30,000 to 40,000 observations for each year_month
table_1 = df.groupby([df['S_2'].dt.year.rename('year'), df['S_2'].dt.month.rename('month')]).agg({'count'})
table_1
# Out:
#            customer_ID    S_2    P_2   D_39    B_1    B_2    R_1    S_3  \
#                  count  count  count  count  count  count  count  count
# year month
# 2017 3           30237  30237  29803  30237  30237  30221  30237  24566
#      4           31213  31213  30833  31213  31213  31193  31213  25201
#      5           31412  31412  31108  31412  31412  31389  31412  25748
#      6           31788  31788  31516  31788  31788  31764  31788  25898
#      7           32326  32326  32014  32326  32326  32307  32326  25870
#      8           33506  33506  33189  33506  33506  33480  33506  27269
#      9           33699  33699  33304  33699  33699  33683  33699  27521
#      10          34737  34737  34252  34737  34737  34710  34737  28386
#      11          35199  35199  34722  35199  35199  35165  35199  28880
#      12          36662  36662  36221  36662  36662  36637  36662  30198
# 2018 1           39102  39102  38511  39102  39102  39045  39102  32521
# ...

# %%
table_1.to_csv('table_1.csv')

# %%
# distribution count of target variable
df['target'].value_counts(normalize=True)
# Out:
# 0    0.741066
# 1    0.258934
# Name: target, dtype: float64

# %%
# split the data into month_year
mar_2017 = df[(df['S_2'] >= '2017-03-01') & (df['S_2'] <= '2017-03-31')]
apr_2017 = df[(df['S_2'] >= '2017-04-01') & (df['S_2'] <= '2017-04-30')]
may_2017 = df[(df['S_2'] >= '2017-05-01') & (df['S_2'] <= '2017-05-31')]
jun_2017 = df[(df['S_2'] >= '2017-06-01') & (df['S_2'] <= '2017-06-30')]
jul_2017 = df[(df['S_2'] >= '2017-07-01') & (df['S_2'] <= '2017-07-31')]
aug_2017 = df[(df['S_2'] >= '2017-08-01') & (df['S_2'] <= '2017-08-31')]
sep_2017 = df[(df['S_2'] >= '2017-09-01') & (df['S_2'] <= '2017-09-30')]
oct_2017 = df[(df['S_2'] >= '2017-10-01') & (df['S_2'] <= '2017-10-31')]
nov_2017 = df[(df['S_2'] >= '2017-11-01') & (df['S_2'] <= '2017-11-30')]
dec_2017 = df[(df['S_2'] >= '2017-12-01') & (df['S_2'] <= '2017-12-31')]
jan_2018 = df[(df['S_2'] >= '2018-01-01') & (df['S_2'] <= '2018-01-31')]
feb_2018 = df[(df['S_2'] >= '2018-02-01') & (df['S_2'] <= '2018-02-28')]
mar_2018 = df[(df['S_2'] >= '2018-03-01') & (df['S_2'] <= '2018-03-31')]

# %%
print('Default rate for time period 2017-03-01 to 2017-03-31: ', sum(mar_2017['target'])/len(mar_2017['target']))
print('Default rate for time period 2017-03-01 to 2017-03-31: ', sum(apr_2017['target'])/len(apr_2017['target']))
print('Default rate for time period 2017-03-01 to 2017-03-31: ', sum(may_2017['target'])/len(may_2017['target']))
print('Default rate for time period 2017-03-01 to 2017-03-31: ', sum(jun_2017['target'])/len(jun_2017['target']))
print('Default rate for time period 2017-03-01 to 2017-03-31: ', sum(jul_2017['target'])/len(jul_2017['target']))
print('Default rate for time period 2017-03-01 to 2017-03-31: ', sum(aug_2017['target'])/len(aug_2017['target']))
print('Default rate for time period 2017-03-01 to 2017-03-31: ', sum(sep_2017['target'])/len(sep_2017['target']))
print('Default rate for time period 2017-03-01 to 2017-03-31: ', sum(oct_2017['target'])/len(oct_2017['target']))
print('Default rate for time period 2017-03-01 to 2017-03-31: ', sum(nov_2017['target'])/len(nov_2017['target']))
print('Default rate for time period 2017-03-01 to 2017-03-31: ', sum(dec_2017['target'])/len(dec_2017['target']))
print('Default rate for time period 2017-03-01 to 2017-03-31: ', sum(jan_2018['target'])/len(jan_2018['target']))
print('Default rate for time period 2017-03-01 to 2017-03-31: ', sum(feb_2018['target'])/len(feb_2018['target']))
print('Default rate for time period 2017-03-01 to 2017-03-31: ', sum(mar_2018['target'])/len(mar_2018['target']))
# Out:
# Default rate for time period 2017-03-01 to 2017-03-31:  0.2323643218573271
# Default rate for time period 2017-03-01 to 2017-03-31:  0.23791368980873354
# Default rate for time period 2017-03-01 to 2017-03-31:  0.2370113332484401
# Default rate for time period 2017-03-01 to 2017-03-31:  0.2527997986661633
# Default rate for time period 2017-03-01 to 2017-03-31:  0.2522118418610407
# Default rate for time period 2017-03-01 to 2017-03-31:  0.253238225989375
# Default rate for time period 2017-03-01 to 2017-03-31:  0.25804920027300515
# Default rate for time period 2017-03-01 to 2017-03-31:  0.2579670092408671
# Default rate for time period 2017-03-01 to 2017-03-31:  0.2641268217847098
# Default rate for time period 2017-03-01 to 2017-03-31:  0.26809775789645957
# Default rate for time period 2017-03-01 to 2017-03-31:  0.27274819702317016
# Default rate for time period 2017-03-01 to 2017-03-31:  0.27273378375152196
# ...

# %% [markdown]
# # EDA #

# %%
# are there missing customer IDs and duplicated customer IDs?
df.customer_ID.isna().any(), df.customer_ID.duplicated().any()
# Out:
# (False, False)

# %%
print('Train statement dates: ', df.S_2.min(), df.S_2.max())
print(f'Train data memory usage: {df.memory_usage().sum() / 1e9} GBytes')
# Out:
# Train statement dates:  2017-03-01 00:00:00 2018-03-31 00:00:00
# Train data memory usage: 0.701219192 GBytes

# %%
#S_2 is datetime
# customer_id, D_63 and D_64 are objects while the rest are numeric

df.info(max_cols=200, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458913 entries, 0 to 458912
# Data columns (total 191 columns):
#  #    Column       Non-Null Count   Dtype
# ---   ------       --------------   -----
#  0    customer_ID  458913 non-null  object
#  1    S_2          458913 non-null  datetime64[ns]
#  2    P_2          453274 non-null  float64
#  3    D_39         458913 non-null  float64
#  4    B_1          458913 non-null  float64
#  5    B_2          458571 non-null  float64
#  6    R_1          458913 non-null  float64
#  7    S_3          374970 non-null  float64
#  8    D_41         458571 non-null  float64
#  9    B_3          458571 non-null  float64
#  10   D_42         85910 non-null   float64
#  11   D_43         309705 non-null  float64
#  12   D_44         434522 non-null  float64
#  13   B_4          458913 non-null  float64
#  14   D_45         458570 non-null  float64
#  15   B_5          458913 non-null  float64
#  16   R_2          458913 non-null  float64
# ...

# %%
# calculate % of missing values for each column
# there are many columns with missing values. If we use neural networks and other estimators, we will need to impute values.
# if we choose a decision-tree based model, we don't need to change the missing values
df.isna().mean()*100
# Out:
# customer_ID     0.000000
# S_2             0.000000
# P_2             1.228773
# D_39            0.000000
# B_1             0.000000
# B_2             0.074524
# R_1             0.000000
# S_3            18.291702
# D_41            0.074524
# B_3             0.074524
# D_42           81.279676
# D_43           32.513352
# D_44            5.314951
# B_4             0.000000
# D_45            0.074742
# B_5             0.000000
# R_2             0.000000
# D_46           25.784190
# D_47            0.000000
# D_48           13.256107
# D_49           90.017934
# B_6             0.026367
# B_7             0.000000
# B_8             0.943970
# D_50           57.690891
# D_51            0.000000
# B_9             0.000000
# R_3             0.000000
# D_52            0.855500
# P_3            10.145496
# B_10            0.000000
# D_53           74.837932
# S_5             0.000000
# B_11            0.000000
# S_6             0.000000
# D_54            0.074524
# R_4             0.000000
# ...

# %%
# checking for duplicated values
df.duplicated().sum()

# %%
# let's check the statistical summary of the data
# looking at the following table, seems like there are some outliers
# when modeling a neural network, we can use 1 percentile as floor and 99 percentile as cap
df.describe(percentiles=[0.01, 0.25, 0.50, 0.99]).T

# %% [markdown]
# # Categorical Features #
# There are 11 categorical features: ['B_30', 'B_38', 'D_114', 'D_116', 'D_117', 'D_120', 'D_126', 'D_63', 'D_64', 'D_66', 'D_68']

# %%
# how many categories are in each feature?
# we made an assumption that all categorical features below have ordinal relationships existing within except for D_63 and D_64 (we have no reasons to assume otherwise given that variables are anonymized).

cat_features = ['B_30', 'B_38', 'D_114', 'D_116', 'D_117', 'D_120', 'D_126', 'D_63', 'D_64', 'D_66', 'D_68']
for column in cat_features:
    print(df[column].value_counts(dropna=False))
    print("-" * 50)

# %%
### function to plot distributions wrt target


def distribution_plot_wrt_target(data, predictor, target):

    fig, axs = plt.subplots(2, 2, figsize=(12, 10))

    target_uniq = data[target].unique()

    axs[0, 0].set_title("Distribution of target for target=" + str(target_uniq[0]))
    sns.histplot(
        data=data[data[target] == target_uniq[0]],
        x=predictor,
        kde=True,
        ax=axs[0, 0],
        color="teal",
        stat="density",
    )

    axs[0, 1].set_title("Distribution of target for target=" + str(target_uniq[1]))
    sns.histplot(
        data=data[data[target] == target_uniq[1]],
        x=predictor,
        kde=True,
        ax=axs[0, 1],
        color="orange",
        stat="density",
    )

    axs[1, 0].set_title("Boxplot w.r.t target")
    sns.boxplot(data=data, x=target, y=predictor, ax=axs[1, 0], palette="gist_rainbow")

    axs[1, 1].set_title("Boxplot (without outliers) w.r.t target")
    sns.boxplot(
        data=data,
        x=target,
        y=predictor,
        ax=axs[1, 1],
        showfliers=False,
        palette="gist_rainbow",
    )

    plt.tight_layout()
    plt.show()

# %%
def stacked_barplot(data, predictor, target):
    """
    Print the category counts and plot a stacked bar chart

    data: dataframe
    predictor: independent variable
    target: target variable
    """
    count = data[predictor].nunique(dropna=False)
    sorter = data[target].value_counts(dropna=False).index[-1]
    tab1 = pd.crosstab(data[predictor], data[target], margins=True).sort_values(
        by=sorter, ascending=False
    )
    print(tab1)
    print("-" * 120)
    tab = pd.crosstab(data[predictor], data[target], normalize="index").sort_values(
        by=sorter, ascending=False
    )
    tab.plot(kind="bar", stacked=True, figsize=(count + 5, 5))
    plt.legend(
        loc="lower left", frameon=False,
    )
    plt.legend(loc="upper left", bbox_to_anchor=(1, 1))
    plt.show()

# %%
stacked_barplot(df, "B_30", "target")

# %%
plt.figure(figsize=(16, 16))
for i, f in enumerate(cat_features):
    plt.subplot(4, 3, i+1)
    temp = pd.DataFrame(df[f][df.target == 0].value_counts(dropna=False, normalize=True).sort_index().rename('count'))
    temp.index.name = 'value'
    temp.reset_index(inplace=True)
    plt.bar(temp.index, temp['count'], alpha=0.5, label='target=0')
    temp = pd.DataFrame(df[f][df.target == 1].value_counts(dropna=False, normalize=True).sort_index().rename('count'))
    temp.index.name = 'value'
    temp.reset_index(inplace=True)
    plt.bar(temp.index, temp['count'], alpha=0.5, label='target=1')
    plt.xlabel(f)
    plt.ylabel('frequency')
    plt.legend()
    plt.xticks(temp.index, temp.value)
plt.suptitle('Categorical features', fontsize=20, y=0.93)
plt.show()
del temp

# %% [markdown]
# # Numerical Features #
# There are 175 numerical features.

# %%
cont_features = sorted([f for f in train.columns if f not in cat_features + ['customer_ID', 'target', 'S_2']])
print(len(cont_features))
# print(cont_features)
ncols = 4
for i, f in enumerate(cont_features):
    if i % ncols == 0:
        if i > 0: plt.show()
        plt.figure(figsize=(16, 3))
        if i == 0: plt.suptitle('Continuous features', fontsize=20, y=1.02)
    plt.subplot(1, ncols, i % ncols + 1)
    plt.hist(train[f], bins=200)
    plt.xlabel(f)
plt.show()

# %%
train.describe().transpose()

# %%
# identify columns that contain single values. [D_87 and B_31 needs investigation (not mentioned as categorical but have 1 or 2 unique values)]
train.nunique()

# %%
#from our inspection above, non-ordinal relationships are assumed to exist for the categorical features 'D_63' and 'D_64'
from sklearn.preprocessing import OneHotEncoder
# create OneHotEncoder object
encoder = OneHotEncoder()
# fit and transform the data
encoded_data = encoder.fit_transform(train[['D_63', 'D_64']]).toarray()

# %%
# create a new DataFrame with the encoded data
encoded_df = pd.DataFrame(encoded_data, columns=encoder.get_feature_names(['D_63', 'D_64']))

# %%
encoded_df.info()

# %%
encoded_df

# %%
#why do you think it's essential to remove -1 and nan
#encoded_df = encoded_df.drop('D_64_nan', axis=1)
#encoded_df = encoded_df.drop('D_64_-1', axis=1)

# %%
combined_df = pd.concat([train, encoded_df], axis=1)

# %%
combined_df

# %%
combined_df = combined_df.drop('D_63', 'D_64', axis=1)
combined_df

# %%
combined_df.info(max_cols=200, show_counts=True)

# %%
# combined_df.to_csv('combined_df.csv')

# %%
import xgboost as xgb

# %%
# run XGBoost
X_train = combined_df.drop('target', axis=1)
Y_train = combined_df['target']

# %%
X_train = X_train.drop('customer_ID', 'S_2' axis=1)

xgb_instance = xgb.XGBClassifier(random_state = 7) # nothing inside paranthesis, meaning we are using default parameters, with 100 trees.
model_for_feature_selection = xgb_instance.fit(X_train, Y_train)

# %%
# check the importances - you can also use SHAP values
feature_importance = {'Feature':X_train.columns,'Importance':model_for_feature_selection.feature_importances_}
feature_importance = pd.DataFrame(feature_importance)
feature_importance.sort_values("Importance", inplace=True,ascending=False)
feature_importance

# %%
model_for_feature_selection

# %%
# choose features with FI higher than 0.5%
final_features = feature_importance["Feature"][feature_importance.Importance > 0.005]

# %%
final_features

# %%
final_features.info()

# %%
# define the train, test1, and test2 date ranges
train_start_date = '2017-05-01'
train_end_date = '2018-01-31'
test1_start_date = '2017-03-01'
test1_end_date = '2017-04-30'
test2_start_date = '2018-02-01'
test2_end_date = '2018-03-31'

# split the data into train, test1, and test2 samples based on the date ranges
xtrain = combined_df[(combined_df['S_2'] >= train_start_date) & (combined_df['S_2'] <= train_end_date)]
test1 = combined_df[(combined_df['S_2'] >= test1_start_date) & (combined_df['S_2'] <= test1_end_date)]
test2 = combined_df[(combined_df['S_2'] >= test2_start_date) & (combined_df['S_2'] <= test2_end_date)]
ytrain = xtrain['target']
xtrain = xtrain.drop('target', axis=1)
xtrain = xtrain.drop('customer_ID', axis=1)
xtrain = xtrain.drop('S_2', axis=1)

# %%
xgb_instance2 = xgb.XGBClassifier(random_state = 7) # nothing inside paranthesis, meaning we are using default parameters, with 100 trees.
model_for_feature_selection_2 = xgb_instance2.fit(xtrain, ytrain)

# %%
feature_importance2 = {'Feature':xtrain.columns,'Importance':model_for_feature_selection_2.feature_importances_}
feature_importance2 = pd.DataFrame(feature_importance2)
feature_importance.sort_values("Importance", inplace=True,ascending=False)
feature_importance2

# %%
# choose features with FI higher than 0.5%
final_features2 = feature_importance2["Feature"][feature_importance2.Importance > 0.005]

feature_importance2.to_csv('featureimpwoparam.csv', index=False)
final_features2

# %%
final_features2.info()

# %%
# Define XGBoost hyperparameters
params = {
    "objective": "binary:logistic",
    "n_estimators": 300,
    "learning_rate": 0.5,
    "max_depth": 4,
    "subsample": 0.5,
    "colsample_bytree": 0.5,
    "scale_pos_weight": 5
}


# Train XGBoost model
model_params = xgb.XGBClassifier(**params, random_state = 7)
model_params.fit(xtrain, ytrain)

feature_importance3 = {'Feature':xtrain.columns,'Importance':model_params.feature_importances_}
feature_importance3 = pd.DataFrame(feature_importance3)
feature_importance.sort_values("Importance", inplace=True,ascending=False)
feature_importance3

# %%
final_features3 = feature_importance3["Feature"][feature_importance3.Importance > 0.005]

# %%
final_features2.to_csv('finalfeatureswoparams.csv',index = False)
final_features3.to_csv('finalfeatureswithparams.csv',index = False)

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import GridSearchCV
import xgboost as xgb


# Define the hyperparameters to tune
params2 = {
    'n_estimators': [50, 100, 300],
    'learning_rate': [0.01, 0.1],
    'subsample': [0.5, 0.8],
    'colsample_bytree': [0.5, 1.0],
    'scale_pos_weight': [1, 5, 10]
}


# Use GridSearchCV to find the best hyperparameters
grid_search = GridSearchCV(xgb.XGBClassifier(random_state =7), params2, cv=5, scoring='accuracy')
grid_search.fit(xtrain, ytrain)

# Print the best hyperparameters
print("Best hyperparameters found: ", grid_search.best_params_)
print("Best score: ", grid_search.best_score_)
